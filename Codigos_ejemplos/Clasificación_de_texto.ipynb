# %% [markdown]
# # Clasificacion de texto usando algoritmos de DataLab

# %% [markdown]
# Para esto se utiliza como ejemplo la data del rubro alimentos de Mercado Público:

# %% [markdown]
# *   df_alimentos: https://drive.google.com/file/d/1IMtwgQ1c3Rq1f9iVO_5UTjFUSFmZQjlF/view

# %% [markdown]
# ## 1. Cargar archivos y dependencias

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
df_alimentos= pd.read_csv('/content/drive/MyDrive/df_alimentos.csv')

# %%
df_alimentos.sample(100)
# Out:
#               id                                        buyer_specs  quantity  \
# 466600   7233467                                     Betarragas\r\n      15.0
# 622557   5878127     YOGURT DE LITRO SOPROLE DE FRUTILLA - VAINILLA      10.0
# 319020   4122310                                          CILANTRO.       1.0
# 552135   8620176                                            OREGANO       5.0
# 562471   8756730                           PATE EMBUTIDO DE 150 GRS      50.0
# ...          ...                                                ...       ...
# 754828  11407354  (Cód. interno 010101000122) Sopa: Crema de cha...       4.0
# 140351   1861748  QUESILLO, SIMILAR COLUN O SUPERIOR, EMBUTIDOS ...      70.0
# 702188   8307833                  AGUA MINERAL SIN GAS 1 1/2 LITROS      15.0
# 599506   5398076                                 SALSA DE SOYA 1 LT      12.0
# 654478   7226487                                     KILO DE MANJAR      16.0
#
#                               Rubro  \
# 466600  Alimentos, bebidas y tabaco
# 622557  Alimentos, bebidas y tabaco
# 319020  Alimentos, bebidas y tabaco
# 552135  Alimentos, bebidas y tabaco
# 562471  Alimentos, bebidas y tabaco
# ...                             ...
# 754828  Alimentos, bebidas y tabaco
# 140351  Alimentos, bebidas y tabaco
# 702188  Alimentos, bebidas y tabaco
# 599506  Alimentos, bebidas y tabaco
# 654478  Alimentos, bebidas y tabaco
#
#                                              Clase
# 466600                                    Verduras
# 622557                      Postres y decoraciones
# 319020                                    Verduras
# 552135               Hierbas, especias y extractos
# 562471  Salsas, condimentos y productos para untar
# ...                                            ...
# 754828                           Sopas y estofados
# 140351                                      Quesos
# 702188                      Bebidas no alcohólicas
# 599506                Salmuera, salsas y aceitunas
# 654478            Productos de leche y mantequilla
#
# [100 rows x 5 columns]

# %% [markdown]
# Dependencias: SE RECOMIENDA UTILIZAR GPU

# %%
# Package installation (hidden on docs.cleanlab.ai).
# If running on Colab, may want to use GPU (select: Runtime > Change runtime type > Hardware accelerator > GPU)
# Package versions we used:scikit-learn==1.2.0 sentence-transformers==2.2.2

dependencies = ["cleanlab", "sklearn", "sentence_transformers", "datasets"]

# Supress outputs that may appear if tensorflow happens to be improperly installed:
import os

os.environ["TOKENIZERS_PARALLELISM"] = "false"  # disable parallelism to avoid deadlocks with huggingface

if "google.colab" in str(get_ipython()):  # Check if it's running in Google Colab
    # %pip install cleanlab==v2.4.0
    cmd = ' '.join([dep for dep in dependencies if dep != "cleanlab"])
    # %pip install $cmd
else:
    missing_dependencies = []
    for dependency in dependencies:
        try:
            __import__(dependency)
        except ImportError:
            missing_dependencies.append(dependency)

    if len(missing_dependencies) > 0:
        print("Missing required dependencies:")
        print(*missing_dependencies, sep=", ")
        print("\nPlease install them before running the rest of this notebook.")

# %%
import re
import string
import pandas as pd
from sklearn.metrics import accuracy_score, log_loss
from sklearn.model_selection import cross_val_predict
from sklearn.linear_model import LogisticRegression
from sentence_transformers import SentenceTransformer

from cleanlab import Datalab
import numpy as np

# %%
# This cell is hidden from docs.cleanlab.ai

import random
import numpy as np

#pd.set_option("display.max_colwidth", 10)

SEED = 123456  # for reproducibility
np.random.seed(SEED)
random.seed(SEED)

# %% [markdown]
# ## 1. Definir modelo de clasificación y obtención de probabilidades de predicción.

# %% [markdown]
# Veamos el desbalance de clases

# %%
class_counts = df_alimentos['Clase'].value_counts()
class_porcentaje = df_alimentos['Clase'].value_counts(normalize=True) * 100

# Crear un nuevo DataFrame con las columnas 'Clase', 'Cantidad' y 'Porcentaje'
df_summary = pd.DataFrame({'Clase': class_counts.index,
                           'Cantidad': class_counts.values,
                           'Porcentaje': class_porcentaje.values})

# Imprimir el nuevo DataFrame
df_summary
# Out:
#                                                 Clase  Cantidad  Porcentaje
# 0                                            Verduras    188316   23.757475
# 1                                              Frutas     72318    9.123458
# 2                              Bebidas no alcohólicas     65804    8.301668
# 3                   Pan, galletas y pastelitos dulces     64979    8.197588
# 4                             Carnes y aves de corral     43341    5.467792
# 5                    Productos de leche y mantequilla     39684    5.006434
# 6                                           Café y té     29943    3.777534
# 7                      Carnes procesadas y preparadas     27404    3.457220
# 8    Productos de chocolates, azúcares y edulcorantes     19361    2.442535
# 9                              Postres y decoraciones     17540    2.212802
# 10                      Hierbas, especias y extractos     16805    2.120077
# 11                                           Cereales     16350    2.062675
# 12                                             Quesos     15893    2.005021
# 13                       Pasta o tallarines naturales     14557    1.836475
# 14                       Salmuera, salsas y aceitunas     13294    1.677138
# 15  Jaleas, gelatinas, mermeladas, pastas de untar...     13055    1.646986
# 16                                Huevos y sustitutos     12630    1.593369
# 17                            Productos de confitería     11489    1.449423
# 18                                          Legumbres     10199    1.286680
# 19         Salsas, condimentos y productos para untar      9685    1.221835
# 20                         Tartas, empanadas y pastas      9538    1.203290
# 21                                           Pescados      9432    1.189917
# 22                                Cereales procesados      8138    1.026670
# 23             Aceites vegetales y grasas comestibles      8020    1.011783
# 24                         Acompañamientos preparados      6159    0.777004
# 25                  Materiales y mezclas instantáneas      6127    0.772967
# 26                                Bebidas alcohólicas      5933    0.748492
# 27                                       Frutos secos      5911    0.745717
# 28                Sandwiches y panecillos con relleno      5895    0.743698
# 29                                         Tentempiés      5835    0.736129
# 30                           Empanadas, tartas y pies      4004    0.505135
# 31          Suministros y mezclas para hacer al horno      3813    0.481039
# 32                       Bebidas y comidas infantiles      2850    0.359549
# 33                                  Sopas y estofados      2000    0.252315
# 34                                   Mariscos frescos      1563    0.197184
# 35              Grasas y aceites animales comestibles      1091    0.137638
# 36                        Vinagres y vinos de cocinar      1067    0.134610
# 37                               Ensaladas preparadas       979    0.123508
# 38                     Platos combinados empaquetados       597    0.075316
# 39                                  Plantas acuáticas       483    0.060934
# 40                               Tabaco y substitutos       426    0.053743
# 41    Productos, suministros y accesorios para tabaco       149    0.018797
# 42                            Invertebrados acuáticos         3    0.000378

# %% [markdown]
# Filtremos las clases que tengan muy pocos datos

# %%
filtro = list(df_summary.iloc[-1:].Clase)

# %%
df_filtrado = df_alimentos[~df_alimentos['Clase'].isin(filtro)]

# %%
#df_muestra = df_filtrado.groupby('Clase').apply(lambda x: x.sample(900)).drop(columns='Clase')
#df_muestra = df_muestra.reset_index()
df_muestra = df_filtrado.copy()

# %% [markdown]
# ### Pre-procesamiento de Texto

# %% [markdown]
# Cargamos stopwords

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('punkt')
stopwords_es = set(stopwords.words('spanish'))
# Palabras adicionales para conservar
palabras_a_conservar = {'te'}  # Agrega otras palabras que deseas conservar
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# Funciones auxiliares para generar una descripción más limpia

# %%
import re

def limpiar(texto):
    puntuación = r'[,;.:¡!¿?@#$%&[\](){}<>~=+\-*/|\\_^`"\']'
    patrones_eliminar = r'\b(nº|n°|kg|lt|cm|ml|mm|lp|km|gr|lp|litro|kilo|metro|centimetro|metros|centimetros|kilogramos|kilos|litros|market|gramos|gramo|grs|kgs|cms|lts|merkat| o|similar|formato|marca|referencia|acuenta|misol|botella|traverso|tipo|rm|cc|pq|k|unidad|lemon stone|lata|x|aal|unidades|paquete|sabor|tradicion|region|v|suministro|individual|aproximado|mensual|anual|colun|soprole|mckay|triton|nestle|tipo|comestible|similar)\b'  # Patrones a eliminar
    palabras_eliminar = ['adquisi', 'servicio', 'contrat', 'articulo', 'accesorio', 'cotizacion',
                        'insumo', 'equipamiento', 'suministro', 'construccion', 'mejoramiento', 'mantencion', 'instalacion', 'compra', 'chica',
                        'arriendo', 'reparacion', 'adjudicada', 'adulto', 'equipo', 'hospital', 'segun',
                        'item', 'bases', 'especificaciones', 'tecnicas', 'adjunt', 'refrigerador', 'marca', 'modelo',
                        'unidad', 'bolsa', 'litro', 'anexo', 'similar', 'linea', 'capacidad', 'descripcion',
                        'equivalente', 'presentacion', 'tipo', 'desechable', 'diametro', 'punta', 'compatible',
                        'catalogo', 'referencia', 'canal', 'caja', 'volumen', 'acuerdo', 'licitacion', 'largo', 'administrat', 'debe', 'valor', 'indicad', 'total', 'neto', 'oferta', 'region', 'indicar', 'nombre', 'fabricante', 'caracter', 'comuna', 'establecimient', 'varios', 'provincia', 'talla', 'entrega', 'superior', 'dias', 'habil', 'vencimiento', 'requiere', 'provision', 'sugiere', 'detalle', 'incluido', 'ejecucion', 'garantia', 'minima', 'cumplen', 'anos',
                        '1', '2', '3', '4', '5', '6', '7', '8', '9', '0', 'rigen', 'proyecto', 'media', 'implementacion', 'municipal', 'convenio', 'marco', 'publico', 'reposicion', 'cesfam']

    # Signos de puntuación
    texto = re.sub(puntuación, ' ', texto)

    # Dígitos [0-9]
    texto = re.sub('\d', ' ', texto)

    # Eliminar patrones específicos
    texto = re.sub(patrones_eliminar, ' ', texto)

    # Eliminar palabras específicas
    for palabra in palabras_eliminar:
        texto = re.sub(r'\b{}\b'.format(palabra), ' ', texto)

    return texto


def normalizar(texto):
    # todo a minúsculas
    texto = texto.lower()

    # tildes y diacríticas
    texto = re.sub('á', 'a', texto)
    texto = re.sub('é', 'e', texto)
    texto = re.sub('í', 'i', texto)
    texto = re.sub('ó', 'o', texto)
    texto = re.sub('ú', 'u', texto)
    texto = re.sub('ü', 'u', texto)
    texto = re.sub('ñ', 'n', texto)

    return texto

# %% [markdown]
# Pre procesamiento Parte 1:

# %%
df_muestraa = df_muestra.copy()
df_muestraa['buyer_specs_2'] = df_muestraa['buyer_specs'].apply(normalizar)
df_muestraa['buyer_specs_2'] = df_muestraa['buyer_specs_2'].apply(limpiar)
df_muestraa
# Out:
#               id               buyer_specs  quantity  \
# 0         232428    JUGO SURTIDO DE 7 GRS.      10.0
# 1         232429                   POROTOS       1.0
# 2         232430             ARROZ GRADO 2       2.0
# 3         232431  HARINA BLANCA DE 5 KILOS       2.0
# 4         232432                    SEMOLA       1.0
# ...          ...                       ...       ...
# 792655  10670297                   TOMATES       7.0
# 792656  10667385                 FRUTILLAS      20.0
# 792657  10667386                      PIÑA      20.0
# 792658  10670295                     PAPAS      30.0
# 792659  10670296                   SURTIDO       6.0
#
#                               Rubro                   Clase  \
# 0       Alimentos, bebidas y tabaco  Bebidas no alcohólicas
# 1       Alimentos, bebidas y tabaco               Legumbres
# 2       Alimentos, bebidas y tabaco                Cereales
# 3       Alimentos, bebidas y tabaco                Cereales
# 4       Alimentos, bebidas y tabaco     Cereales procesados
# ...                             ...                     ...
# 792655  Alimentos, bebidas y tabaco                Verduras
# 792656  Alimentos, bebidas y tabaco                  Frutas
# 792657  Alimentos, bebidas y tabaco                  Frutas
# 792658  Alimentos, bebidas y tabaco                Verduras
# 792659  Alimentos, bebidas y tabaco                Verduras
#
#                buyer_specs_2
# 0       jugo surtido de
# 1                    porotos
# 2              arroz grado
# 3       harina blanca de
# 4                     semola
# ...                      ...
# 792655               tomates
# 792656             frutillas
# 792657                  pina
# 792658                 papas
# 792659               surtido
#
# [792657 rows x 6 columns]

# %% [markdown]
# Pre-procesamiento Parte 2:

# %%
# Tokenización de las descripciones
df_muestraa['buyer_specs_tokens'] = df_muestraa['buyer_specs_2'].apply(nltk.word_tokenize)
# Aplicar eliminación de stopwords con excepción de 'te'
df_muestraa['buyer_specs_tokens'] = df_muestraa['buyer_specs_tokens'].apply(lambda tokens: [token for token in tokens if token.lower() not in stopwords_es or token.lower() in palabras_a_conservar])
# Convertir lista de tokens a cadena de texto
df_muestraa['buyer_specs_processed'] = df_muestraa['buyer_specs_tokens'].apply(lambda tokens: ' '.join(tokens))
df_muestraa['buyer_specs_processed'] = df_muestraa['buyer_specs_processed'].apply(lambda text: re.sub(r'[\(\)\d\W_]', ' ', text))
df_muestraa.sample(10)
# Out:
#              id                                        buyer_specs  quantity  \
# 388070  9305085                                 PISCO SOUR, UNIDAD     34.00
# 8        207961  (1430157 )PURE INSTANTANEO MAGGI BOLSA 2K UNID...     40.00
# 233473  4568076  Endulzante Sucralosa 500 tabletas, Iansa o End...     24.00
# 420377  9768585                                    leche en polvo       4.00
# 560654  8731096                                         Zanahorias      3.20
# 451242  6986054                              CANELA EN POLVO BOLSA     10.00
# 11894     79830                                  POSTA ROSADA BEEF     14.78
# 322509  4182903         QUINOA ALMIFRUT BOLSA 1K UNIDAD XVI REGION      6.00
# 478846  7422644       AAL-0141\r\nCEBOLLAS, VARIEDADES, UNIDAD\r\n     80.00
# 27204    371593                     SOPA EN SOBRE MAGGI VARIEDADES      6.00
#
#                               Rubro  \
# 388070  Alimentos, bebidas y tabaco
# 8       Alimentos, bebidas y tabaco
# 233473  Alimentos, bebidas y tabaco
# 420377  Alimentos, bebidas y tabaco
# 560654  Alimentos, bebidas y tabaco
# 451242  Alimentos, bebidas y tabaco
# 11894   Alimentos, bebidas y tabaco
# 322509  Alimentos, bebidas y tabaco
# 478846  Alimentos, bebidas y tabaco
# 27204   Alimentos, bebidas y tabaco
#
#                                                    Clase  \
# 388070                               Bebidas alcohólicas
# 8                                               Verduras
# 233473  Productos de chocolates, azúcares y edulcorantes
# 420377                  Productos de leche y mantequilla
# 560654                                          Verduras
# 451242                    Carnes procesadas y preparadas
# 11894                            Carnes y aves de corral
# 322509                      Pasta o tallarines naturales
# 478846                                          Verduras
# 27204                                  Sopas y estofados
#
#                                             buyer_specs_2  \
# 388070                                      pisco sour
# 8                 pure instantaneo maggi bolsa        ...
# 233473  endulzante sucralosa     tabletas  iansa  endo...
# 420377                                    leche en polvo
# 560654                                         zanahorias
# 451242                              canela en polvo bolsa
# 11894                                   posta rosada beef
# 322509                   quinoa almifrut bolsa      xvi
# 478846                    \r\ncebollas  variedades   \r\n
# 27204                      sopa en sobre maggi variedades
#
#                                        buyer_specs_tokens  \
# 388070                                      [pisco, sour]
# 8                       [pure, instantaneo, maggi, bolsa]
# 233473  [endulzante, sucralosa, tabletas, iansa, endol...
# 420377                                     [leche, polvo]
# 560654                                       [zanahorias]
# 451242                             [canela, polvo, bolsa]
# 11894                               [posta, rosada, beef]
# 322509                     [quinoa, almifrut, bolsa, xvi]
# 478846                             [cebollas, variedades]
# 27204                           [sopa, maggi, variedades]
#
#                                     buyer_specs_processed
# 388070                                         pisco sour
# 8                            pure instantaneo maggi bolsa
# 233473  endulzante sucralosa tabletas iansa endolce ca...
# 420377                                        leche polvo
# 560654                                         zanahorias
# 451242                                 canela polvo bolsa
# 11894                                   posta rosada beef
# 322509                          quinoa almifrut bolsa xvi
# 478846                                cebollas variedades
# 27204                               sopa maggi variedades

# %% [markdown]
# ### Procesamiento: Texto a Tensores con word embeddings

# %%
data = df_muestraa.copy()
data.head()
# Out:
#         id                                 buyer_specs  quantity  \
# 0  4467119                   LÁMINAS PARA TERMOLAMINAR       4.0
# 1  4467121        PACK DE 4 TINTAS 544 COLORES (EPSON)       3.0
# 2  4467123                         DESTACADORES PASTEL      15.0
# 3  4467124       LAPICES DE CERA 12 COLORES GIOTTO PAX      15.0
# 4  4467128  LAPICES DE COLORES ARTEL LARGOS 12 COLORES      15.0
#
#                                           Rubro  \
# 0  Equipos, accesorios y suministros de oficina
# 1  Equipos, accesorios y suministros de oficina
# 2  Equipos, accesorios y suministros de oficina
# 3  Equipos, accesorios y suministros de oficina
# 4  Equipos, accesorios y suministros de oficina
#
#                                              Clase  \
# 0                    Suministros para plastificado
# 1  Suministros para impresora, fax y fotocopiadora
# 2                        Instrumentos de escritura
# 3                        Instrumentos de escritura
# 4                        Instrumentos de escritura
#
#                                        buyer_specs_2  \
# 0                        laminas       termolaminar
# 1           pack   de     tintas       colores
# 2                             destacadores   pastel
# 3   lapices   de   cera      colores   giotto   pax
# 4   lapices   de   colores   artel   largos      ...
#
#                                   buyer_specs_tokens  \
# 0                        ['laminas', 'termolaminar']
# 1                      ['pack', 'tintas', 'colores']
# 2                         ['destacadores', 'pastel']
# 3    ['lapices', 'cera', 'colores', 'giotto', 'pax']
# 4  ['lapices', 'colores', 'artel', 'largos', 'col...
#
#                   buyer_specs_processed
# 0                  laminas termolaminar
# 1                   pack tintas colores
# 2                   destacadores pastel
# 3       lapices cera colores giotto pax
# 4  lapices colores artel largos colores

# %%
raw_texts, labels = data["buyer_specs_processed"].values, data["Clase"].values
num_classes = len(set(labels))

print(f"This dataset has {num_classes} classes.")
print(f"Classes: {set(labels)}")
# Out:
# This dataset has 30 classes.
# Classes: {'Empaquetadoras', 'Máquinas de correo', 'Multicopistas, fotocopiadoras, fax y multifuncionales', 'Máquinas encuadernadoras y plastificadoras', 'Máquinas calculadoras y accesorios', 'Suministros para el manejo de efectivo', 'Suministros de correo', 'Sistemas de planificación', 'Máquinas y accesorios para registro de hora y asistencia en la oficina', 'Máquinas para procesamiento de papel y accesorios', 'Fuibles o fusores y accesorios', 'Máquinas para endosar y extender cheques', 'Suministros de dibujo', 'Etiquetadoras', 'Suministros para impresora, fax y fotocopiadora', 'Máquinas de escribir y accesorios', 'Agendas y accesorios', 'Medios de corrección', 'Suministros de sujeción', 'Suministros para plastificado', 'Accesorios de máquinas de oficina', 'Suministros de escritorio', 'Suministros de máquinas de encuadernar', 'Accesorios para impresoras, fotocopiadoras y aparatos de fax', 'Tableros o pizarras', 'Máquinas clasificadoras', 'Instrumentos de escritura', 'Carpetas de archivo y separadores', 'Accesorios para escáneres', 'Recambios de tinta y minas de lápices'}

# %% [markdown]
# Este paso puede demorar desde 3 min hasta horas, dependiendo la dimensión de los datos:

# %%
transformer = SentenceTransformer('google/electra-small-discriminator')
text_embeddings = transformer.encode(raw_texts)
# Out:
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name /root/.cache/torch/sentence_transformers/google_electra-small-discriminator. Creating a new one with MEAN pooling.
# Some weights of the model checkpoint at /root/.cache/torch/sentence_transformers/google_electra-small-discriminator were not used when initializing ElectraModel: ['discriminator_predictions.dense_prediction.weight', 'discriminator_predictions.dense.weight', 'discriminator_predictions.dense_prediction.bias', 'discriminator_predictions.dense.bias']
# - This IS expected if you are initializing ElectraModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ElectraModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %% [markdown]
# ### Modelo de clasificación
# Aca se puede usar uno a elección. De momento el de mejor resultados es Balanced Random Forest

# %%
from imblearn.ensemble import BalancedRandomForestClassifier
model = BalancedRandomForestClassifier(class_weight="balanced")
pred_probs = cross_val_predict(model, text_embeddings, labels, method="predict_proba")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# ...
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(

# %% [markdown]
# ## 4. Aplicando CleanLab para encontrar anomalías

# %% [markdown]
# Se guarda la data en un diccionario

# %%
data_dict = {"texts": raw_texts, "labels": labels}

# %% [markdown]
# Se aplica DataLab ingresando las probabilidades pronosticadas y las text embeddings obtenidas anteriormente.

# %%
lab = Datalab(data_dict, label_name="labels")
lab.find_issues(pred_probs=pred_probs, features=text_embeddings)

# %% [markdown]
# Reporte:

# %%
#Data pre procesada
lab.report()

# %% [markdown]
# ### Etiquetas erróneas
#
# CleanLab detecta etiquetas con problemas, a través de 2 indicadores, 'is_label_issue' y 'label_score'. Label_score indica un valor entre 0 y 1, donde un valor cercano a 0 indica una mayor probabilidad de error en la etiqueta original.

# %%
label_issues = lab.get_issues("label")
label_issues

# %% [markdown]
# Armamos un nuevo dataframe incluyendo las métricas en el original.

# %%
df_reetiquetas = label_issues.copy()
df_reetiquetas['id'] = df_muestra.id
df_reetiquetas['descripcion'] = df_muestra.buyer_specs
df_reetiquetas['Clase'] = df_muestra.Clase
df_reetiquetas = df_reetiquetas[['id','descripcion','Clase','predicted_label','is_label_issue','label_score']]
df_reetiquetas

# %% [markdown]
# ### Outlier issues
#
# According to the report, our dataset contains some outliers.
# We can see which examples are outliers (and a numeric quality score quantifying how typical each example appears to be) via `get_issues`. We sort the resulting DataFrame by cleanlab's outlier quality score to see the most severe outliers in our dataset.

# %%
outlier_issues = lab.get_issues("outlier")
outlier_issues.sort_values("outlier_score")
df_final = pd.merge(df_reetiquetas,outlier_issues,left_index=True,right_index=True)
df_final.sort_values('outlier_score')

# %% [markdown]
# We see that cleanlab has identified entries in this dataset that do not appear to be proper customer requests. Outliers in this dataset appear to be out-of-scope customer requests and other nonsensical text which does not make sense for intent classification. Carefully consider whether such outliers may detrimentally affect your data modeling, and consider removing them from the dataset if so.

# %% [markdown]
# #Dataframe procesado

# %%
df_final

# %%
df_final.query('is_label_issue == True & label_score <=0.3').sort_values('label_score',ascending=False).head(60)

# %%
# Crear una copia del DataFrame original
df_final_corrected = df_final.copy()

# Aplicar la condición y actualizar los valores en la nueva columna
mask = (df_final['is_label_issue'] == True) & (df_final['label_score'] <= 0.3)
df_final_corrected.loc[mask, 'Clase_nueva'] = df_final.loc[mask, 'predicted_label']
df_final_corrected.loc[~mask, 'Clase_nueva'] = df_final.loc[~mask, 'Clase']

df_final_corrected

# %%
df_final_corrected[['id','descripcion','Clase_nueva']].sample(100)
